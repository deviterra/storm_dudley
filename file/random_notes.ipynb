# %% [markdown]
# Dimensions:
# longitude: 289latitude: 163time: 125
# Coordinates:
# longitude
# (longitude)
# float32
# -27.0 -26.75 -26.5 ... 44.75 45.0
# latitude
# (latitude)
# float32
# 73.5 73.25 73.0 ... 33.5 33.25 33.0
# time
# (time)
# datetime64[ns]
# 2022-02-10 ... 2022-02-20
# Data variables:
#
# sst
# (time, latitude, longitude)
# float32
# ...
#
# fg10
# (time, latitude, longitude)
# float32
# ...
#
# units :
# m s**-1
# long_name :
# 10 metre wind gust since previous post-processing
#
# tcw
# (time, latitude, longitude)
# float32
# ...
# units :
# kg m**-2
# long_name :
# Total column water
#
#
# tcwv
# (time, latitude, longitude)
# float32
# ...
# units :
# kg m**-2
# long_name :
# Total column vertically-integrated water vapour
# standard_name :
# lwe_thickness_of_atmosphere_mass_content_of_water_vapor
#
#
# msl
# (time, latitude, longitude)
# float32
# ...
# units :
# Pa
# long_name :
# Mean sea level pressure
# standard_name :
# air_pressure_at_mean_sea_level
#
#
# tcc
# (time, latitude, longitude)
# float32
# ...
# units :
# (0 - 1)
# long_name :
# Total cloud cover
# standard_name :
# cloud_area_fraction
#
#
# mxtpr
# (time, latitude, longitude)
# float32
# ...
# units :
# kg m**-2 s**-1
# long_name :
# Maximum total precipitation rate since previous post-processing
#
#
# tp
# (time, latitude, longitude)
# float32
# ...
# units :
# m
# long_name :
# Total precipitation
#
#
# u10
# (time, latitude, longitude)
# float32
# ...
# units :
# m s**-1
# long_name :
# 10 metre U wind component
#
#
# v10
# (time, latitude, longitude)
# float32
# ...
# units :
# m s**-1
# long_name :
# 10 metre V wind component
#
#
# u100
# (time, latitude, longitude)
# float32
# ...
# units :
# m s**-1
# long_name :
# 100 metre U wind component
#
#
# v100
# (time, latitude, longitude)
# float32
# ...
# units :
# m s**-1
# long_name :
# 100 metre V wind component
#
#
# mxcape6
# (time, latitude, longitude)
# float32
# ...
# units :
# J kg**-1
# long_name :
# Maximum CAPE in the last 6 hours
#
#
# mxcapes6
# (time, latitude, longitude)
# float32
# ...
# units :
# m**2 s**-2
# long_name :
# Maximum CAPES in the last 6 hours

# %% [markdown]
# If we want to looka the jet stream, where can we get the data? obv the experiments themselves are not making a lot of sense I believe?
#
# Rossby wave observable on 500hPa, which is still some 5km above surface. How are we going to obtain this upper level data??

# %% [markdown]
# We use the ERA-Interim reanalysis from the European Centre for Medium Range Weather Forecasts(ECMWF)(Dee et al., 2011), which is available at a triangular truncation of T255 with a 6-hourly time inter-val providing analyses at 00, 06, 12, and 18 UTC.
#
# We interpolated the data onto a 0.5-degree grid and use thethree-dimensional wind field, geopotential heightz, temperatureT, and diabatic heating.𝜃at 23 pressurelevels (925, 900, 875, 850, 825, 800, 775, 750, 700, 650, 600, 550, 500, 450, 400, 350, 300, 250, 200, 150, and 100hPa).
#
# The precipitation and the diabatic heating at the four analysis times were derived using the 6-hourlyaccumulated values around the respective time steps using the 00 and 12 UTC ERA-Interim forecasts(for details see supporting information).

# %% [markdown]
# Oh yes, I can install ERA5 of course, but this doesn't necessarily make a lot of sense since there is no upper atmosphere or even troposphere data for IFS model, which means that it's impossible to perform different CO2 regime intercomparison.
#
# Which means, is it actually useful to look at ERA5 data at all???
#
#
# Or maybe I can try to calculate the isentrope????
#
#
# How did Nick calculated the z500 geopotential hight in the first instance. Oh he has another dataset. No wonder.
#
# Bruhhhhhh
